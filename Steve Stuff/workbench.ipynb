# %%
import pandas as pd

# %%
def get_hwyrail():
    df = pd.read_csv('rail_data/hwy_rail_accidents_2012.csv', index_col=False)
    df1 = pd.read_csv('rail_data/hwy_rail_accidents_2013.csv', index_col=False)  
    df2 = pd.read_csv('rail_data/hwy_rail_accidents_2014.csv', index_col=False)  
    df3 = pd.read_csv('rail_data/hwy_rail_accidents_2015.csv', index_col=False)  
    df4 = pd.read_csv('rail_data/hwy_rail_accidents_2016.csv', index_col=False)  
    df5 = pd.read_csv('rail_data/hwy_rail_accidents_2017.csv', index_col=False)  
    df6 = pd.read_csv('rail_data/hwy_rail_accidents_2018.csv', index_col=False)  
    df7 = pd.read_csv('rail_data/hwy_rail_accidents_2019.csv', index_col=False)  
    df8 = pd.read_csv('rail_data/hwy_rail_accidents_2020.csv', index_col=False) 
    big_df = pd.concat([df, df1, df2, df3, df4, df5, df6, df7, df8])
    return big_df

# %%
hwy_df = get_hwyrail()
hwy_df
# Out:
#      AMTRAK  IYR  IMO RAILROAD    INCDTNO  IYR2  IMO2   RR2    INCDTNO2  IYR3  \
# 0       NaN   12    3     UP    0312RS009   NaN   NaN                    12.0
# 1       NaN   12    3     UP    0312RS025   NaN   NaN                    12.0
# 2       NaN   12   10     BNSF  CA1012201   NaN   NaN                    12.0
# 3       NaN   12   10     BNSF  CA1012202   NaN   NaN                    12.0
# 4       NaN   12    7     BNSF  CA0712201   NaN   NaN                    12.0
# ...     ...  ...  ...      ...        ...   ...   ...   ...         ...   ...
# 1886    NaN   20    2     SFRV    2132020   NaN   NaN                    20.0
# 1887    NaN   20    1     SFRV    1052020   NaN   NaN                    20.0
# 1888    NaN   20    1     SFRV    1092020   NaN   NaN                    20.0
# 1889    NaN   20    1     SFRV    1172020   NaN   NaN                    20.0
# 1890    NaN   20   11     SFRV   11222020   NaN   NaN                    20.0
#
#       ...                                              NARR1  \
# 0     ...  HIEHWAY USER'S ACTIONS: STOPPED ON CROSSING ( ...
# 1     ...  HIGHWAY USER'S ACTIONS: STOPPED ON CROSSING ( ...
# 2     ...          DRIVER AGE UNKNOW.  41: ABANDONED VEHICLE
# 3     ...  12/18/12 PER CONTRA COSTA COUNTY CORONERS REPO...
# 4     ...                                                NaN
# ...   ...                                                ...
# 1886  ...  TRAIN P645 WAS TRAVELLING SOUTHBOUND AND STRUC...
# 1887  ...  TWO MALES ON A BICYCLE RAN UNDER CROSSING GATE...
# 1888  ...  TRAIN P647 STRUCK A VEHICLE THAT STOPPED ON TH...
# 1889  ...  TRAIN P628 STRUCK A VEHICLE THAT STOPPED ON TH...
# 1890  ...  TRAIN P686 STRUCK AN EMPTY VEHICLE AT NW 27TH ...
#
#                                                   NARR2  \
# 0                                                   NaN
# 1                                     D LEFT THE SCENE.
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1886           ALLY INJURED; AGE IS CURRENTLY UNKNOWN.
# 1887  HE BIKE WAS HIT AND KILLED WHILE THE OTHER ONE...
# 1888  CT. HE WAS TRAVELING EAST IN THE WESTBOUND TRA...
# 1889                                        UNINJURED.
# 1890                                                NaN
#
#                                                   NARR3  NARR4  NARR5  \
# 0                                                   NaN    NaN    NaN
# 1                                                   NaN    NaN    NaN
# 2                                                   NaN    NaN    NaN
# 3                                                   NaN    NaN    NaN
# 4                                                   NaN    NaN    NaN
# ...                                                 ...    ...    ...
# 1886                                                NaN    NaN    NaN
# 1887  PORT IS PENDING SO AGE OF DECEASED IS STILL UN...    NaN    NaN
# 1888                                                NaN    NaN    NaN
# 1889                                                NaN    NaN    NaN
# 1890                                                NaN    NaN    NaN
#
#                     SUBDIV  ROADCOND  VIDEOT  VIDEOU  Unnamed: 103
# 0     WOODBRIDGE                   B       1       2           NaN
# 1     FRESNO SUB                   A       1       2           NaN
# 2     SAN BERNARDINO               A       1       2           NaN
# 3     STOCKTON                     A       1       1           NaN
# 4     STOCKTON                     A       1       2           NaN
# ...                    ...       ...     ...     ...           ...
# 1886  SOUTHFLRAILCORRIDOR          A       2       2           NaN
# 1887  SOUTHFLRAILCORRIDOR          A       1       1           NaN
# 1888  SOUTHFLRAILCORRIDOR          A       1       1           NaN
# 1889  SOUTHFLRAILCORRIDOR          A       2       2           NaN
# 1890  SOUTHFLRAILCORRIDOR          A       2       2           NaN
#
# [18995 rows x 104 columns]

# %%
equip_df = pd.read_csv('')
